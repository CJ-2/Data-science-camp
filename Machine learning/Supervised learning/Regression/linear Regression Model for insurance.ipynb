# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder

# %%
insurance = pd.read_csv('insurance.csv')
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance.isnull().sum()#the dataset is clean
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#EDA

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance.describe(include=object)
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
#LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(insurance['sex']).classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
insurance['sex'] = le.transform(insurance['sex'])

# %%
le.fit(insurance['smoker']).classes_
# Out:
# array(['no', 'yes'], dtype=object)

# %%
insurance['smoker'] = le.transform(insurance['smoker'])

# %%
le.fit(insurance['region']).classes_
# Out:
# array(['northeast', 'northwest', 'southeast', 'southwest'], dtype=object)

# %%
insurance['region'] = le.transform(insurance['region'])

# %%
insurance
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
#visualisation

# %%
sns.histplot(data=insurance['charges']);

# %%
sns.pairplot(data=insurance);

# %%
plt.figure(figsize=(10,6))
sns.heatmap(insurance.corr(),annot=True);

# %%
#The relationship between age and Charges

# %%
plt.figure(figsize=(10,6))
sns.jointplot(data=insurance,x='charges',y='age',kind='reg');

# %%
#The relationship between sex and Charges

# %%
plt.figure(figsize=(10,10))
sns.jointplot(data=insurance,x='charges',y='sex',kind='reg');

# %%
#The relationship between bmi and Charges

# %%
plt.figure(figsize=(10,10))
sns.jointplot(data=insurance,x='charges',y='bmi',kind='reg');

# %%
#The relationship between children and Charges

# %%
plt.figure(figsize=(10,10))
sns.jointplot(data=insurance,x='charges',y='children',kind='reg');

# %%
#The relationship between smoker and Charges

# %%
plt.figure(figsize=(10,10))
sns.jointplot(data=insurance,x='charges',y='smoker',kind='reg');

# %%
#The relationship between region and Charges

# %%
plt.figure(figsize=(10,10))
sns.jointplot(data=insurance,x='charges',y='region',kind='reg');

# %%
#Training & Testing Split

# %%
x = insurance.drop('charges',axis=1)
y = insurance['charges']

# %%
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
x_train ,x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=23)

# %%
x_train.shape
# Out:
# (1070, 6)

# %%
x_test.shape
# Out:
# (268, 6)

# %%
y_train.shape
# Out:
# (1070,)

# %%
y_test.shape
# Out:
# (268,)

# %%
#Model Training

# %%
lm = LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(x_test)
predictions
# Out:
# array([11604.93749877,  6560.20111768, 31555.11889527, 10181.93873375,
#         8077.83282199,  9477.37304927, 35682.14712075,  8562.02362597,
#        13018.32610365, 39388.39629574,  1721.52571177, 36917.91043736,
#         4341.49112814, 12467.01697235,  8171.06089387,  5289.88853358,
#         5572.07255876,  3738.22720523, 35255.7488549 , 32949.76179957,
#        38712.39438971, 13410.78376729,  8297.60927423,  9866.39219619,
#        35734.42594059,  7109.31653217,  5467.41181341, 29171.46496585,
#          731.23228693, 11301.48297383, 13668.7601629 ,  4997.77873415,
#         4106.30660085, 12042.8050281 ,  9020.2809711 , 29202.35651956,
#        11268.84913901, 10685.27802796,  9933.32798142,  4614.49811647,
#        11079.95408659, 34041.69966965, 11316.43971152, 31865.75903074,
#        11476.46881181, 13452.24351872,  4505.60049454,  5602.94615451,
#         8813.37625929,  5546.66374721, 13438.80148435,  9055.7137137 ,
#        10490.70918064,  5713.37247527,  6441.27677356, 14492.91233091,
#        14334.34480374, 11944.89324892,  7704.6436924 , 27835.81819642,
#        29750.97831785,  6027.38113745,  3580.83795412,  6310.19459952,
#         3510.57765988,  6880.27125347,  4963.71921784,  4537.79314499,
#         4315.10067559, 24799.46717593,  7410.72507371, 34451.77927332,
#         8652.49852506, 30893.03857935,  2520.42564711,  5933.36246823,
#        10207.59102078,  4305.12637612,  6727.86720834,  4494.04783219,
#        12682.9228117 ,  3661.53242011, 30670.72748549, 15469.82741342,
#         7111.5169692 ,  9804.62318172, 16871.27389592, 38227.74551816,
#         2857.47769081, 35838.2296054 ,  7141.25231258, 12128.23563322,
#         1331.10908264, 10066.26010475, 36013.12813792,   842.31730432,
#         2136.44627663,  5125.31542078, 28332.00281465, -1586.81859604,
#        11605.12292854,  6933.49442682,   743.37884753,  8868.22739462,
#        11935.42493221,  9980.34152978,  8789.88497318,  1900.89437841,
#         4312.9639306 ,  7886.27364201, 26124.68154584, 10061.94934977,
#         7097.96336007, 10045.76086283, 12510.89983221,  4711.19109962,
#        40366.48511429, 14465.64512347, 29730.96038052,  4678.71556006,
#        11465.30560949, 10715.53341457, 10104.3006556 ,  5515.47067234,
#         3545.61034812,  2231.23297209,  3484.79976101, 33948.92233509,
#         9604.99310228, 27433.52485424, 33458.16904611,  1023.05919724,
#        10935.53296047,  5473.21467721,  9406.50756408,   751.60242838,
#         3007.72072165, 10497.14363904,  2342.30846903,  2930.52670646,
#        13600.5735966 , 16527.05769735, 16418.07670904, 10974.81271165,
#         8280.94294794,  7134.62898164, 36555.43721554,  5147.94855248,
#          561.3752797 ,  7148.87567383, 10933.49649754, 14424.83449326,
#         4155.00895713, 11427.38395026, 25734.70048722,  3083.32688598,
#         4166.04093373,  8290.42927757,  7158.26236391,  6212.47037536,
#         3952.72144696,  6342.73208226,   449.64783882, 14354.43097313,
#         9335.35356681,  6761.91827806, 34154.51573133,  3963.09192667,
#         1634.05762481, 10430.79681319,  2684.18459072, 13878.83673481,
#         3212.77826532,  4663.11532502,  3949.76033733,  7319.74634049,
#        10496.60778648,  5432.25066722, 12161.4098931 ,  6667.67479789,
#         9644.60921577,  8244.62995275, 33616.5258228 ,  1005.28282696,
#        12129.6014643 , 13055.13207253,  2298.43301347, 10688.92379743,
#        23894.99032761, 26748.92642412, 11921.03569822, 34027.6113143 ,
#        12547.88948201,  7451.41289233,  6709.51772049, 33682.02468061,
#         9345.64280539,  9849.24248164, 10802.33549712, 11499.56956402,
#        26882.74310642, 32141.73445894,  -703.27585269,  3632.93699053,
#         6677.15265844,  3997.45576439, 30504.15452315, 10779.13378786,
#        32553.16757298, 12620.15526303, 26416.40994634,  5899.00321209,
#         7308.51490612,  5061.16163675,  7702.63713175, 28267.34592644,
#        26373.52276456,  6502.25519978, 10602.06086895, 13974.68282378,
#        15951.24641166, 16025.42584402,  7244.58876485, 32191.32664415,
#         5803.5898609 , 10718.74361354,  5533.22168036, 13192.37600222,
#         1853.85092777, 18972.92250971, 28725.12933881, 27113.82833668,
#         7734.70803537,  4553.21924295,  4108.95841771,  8396.24122941,
#         8727.20644635,  7879.33884719,  5626.22665767, 35169.11531894,
#         2719.69051335,  9252.01857665, 11164.60813145, 16034.44385476,
#        10358.78469399, 10223.86290658, 29933.38197252,  5504.09039821,
#         9919.30785812,  4131.27032144,   787.77333651, 11651.69244642,
#         6635.88782476,  4485.40277378,  7755.95775443, 28176.3277571 ,
#        12916.22076721, 11315.48906914,  7141.65236694, 34290.82377749,
#        11095.93746032, 36056.54834863, 11273.73056432, 32798.65046045,
#         4813.60640381, 30871.0320618 , 15008.59487571,  -888.42983403])

# %%
real_values = np.array(y_test)#real_values
real_values
# Out:
# array([13041.921  ,  5031.26955, 20984.0936 , 25656.57526,  3201.24515,
#         7256.7231 , 41999.52   , 12404.8791 , 14001.1338 , 47269.854  ,
#         2597.779  , 29330.98315,  2741.948  , 14256.1928 ,  6238.298  ,
#         4746.344  ,  6652.5288 ,  2250.8352 , 41676.0811 , 39836.519  ,
#        47928.03   ,  7650.77375,  6457.8434 , 11837.16   , 42211.1382 ,
#         4837.5823 ,  4894.7533 , 36219.40545,  2201.0971 ,  8556.907  ,
#        12644.589  ,  2473.3341 ,  4032.2407 , 13224.693  ,  5584.3057 ,
#        19350.3689 , 12479.70895,  7261.741  , 30284.64294,  3537.703  ,
#        11165.41765, 40003.33225, 10264.4421 , 21098.55405, 11554.2236 ,
#         9880.068  ,  4340.4409 ,  4435.0942 , 26140.3603 , 27375.90478,
#        11674.13   ,  6338.0756 ,  9724.53   ,  3443.064  ,  3490.5491 ,
#        10579.711  , 10602.385  ,  8527.532  ,  7325.0482 , 33475.81715,
#        35491.64   ,  4076.497  ,  1137.4697 ,  3943.5954 ,  2523.1695 ,
#         5469.0066 , 14133.03775,  1141.4451 ,  4133.64165, 26125.67477,
#         6184.2994 , 39556.4945 ,  7512.267  , 20296.86345,  2155.6815 ,
#         4149.736  ,  9447.3824 ,  4719.52405,  3597.596  ,  3392.3652 ,
#        11353.2276 ,  2130.6759 , 51194.55914, 14474.675  ,  7173.35995,
#         6986.697  , 13831.1152 , 30942.1918 ,  2257.47525, 42856.838  ,
#         4466.6214 , 11658.37915,  2585.85065,  7050.0213 , 42969.8527 ,
#         1969.614  ,  1635.73365,  1534.3045 , 34838.873  ,  1241.565  ,
#        28923.13692,  5484.4673 ,  2913.569  ,  9861.025  , 14451.83515,
#        11830.6072 ,  8027.968  ,  2331.519  ,  3056.3881 ,  6067.12675,
#        17085.2676 ,  7348.142  ,  4449.462  , 11073.176  ,  5757.41345,
#         1646.4297 , 48970.2476 , 11394.06555, 36197.699  ,  2134.9015 ,
#        11085.5868 ,  7371.772  ,  2927.0647 ,  5257.50795,  2639.0429 ,
#        13126.67745,  4544.2348 , 39125.33225,  7441.501  , 16138.76205,
#        39727.614  ,  1252.407  , 11743.299  ,  5312.16985,  5729.0053 ,
#         2803.69785,  1906.35825, 10965.446  , 18955.22017,  1967.0227 ,
#        29186.48236, 14210.53595, 13981.85035,  9957.7216 ,  5245.2269 ,
#         9991.03765, 43896.3763 ,  2219.4451 ,  1515.3449 ,  5028.1466 ,
#         9850.432  , 10736.87075,  2850.68375, 11015.1747 , 15359.1045 ,
#        11272.33139,  4500.33925,  7421.19455,  3393.35635,  2534.39375,
#         2494.022  ,  7222.78625,  2680.9493 , 36910.60803,  5630.45785,
#         4151.0287 , 40273.6455 ,  4185.0979 ,  2709.1119 ,  7160.094  ,
#        14426.07385, 27000.98473,  1135.9407 ,  2166.732  ,  2020.177  ,
#        26236.57997,  9487.6442 ,  4260.744  , 10928.849  ,  2217.6012 ,
#        23563.01618, 10577.087  , 39871.7043 ,  2007.945  , 12638.195  ,
#        14001.2867 ,  2395.17155,  8116.26885, 12829.4551 , 17178.6824 ,
#         8023.13545, 39774.2763 ,  9722.7695 ,  7151.092  ,  6496.886  ,
#        24180.9335 ,  7789.635  ,  9282.4806 ,  8871.1517 , 12146.971  ,
#        15820.699  , 38415.474  ,  1832.094  ,  1263.249  ,  4349.462  ,
#         2566.4707 , 37079.372  , 13451.122  , 23065.4207 ,  9866.30485,
#        15006.57945,  3877.30425,  7046.7222 ,  2416.955  ,  5425.02335,
#        16776.30405, 17468.9839 ,  4646.759  , 10106.13425, 12244.531  ,
#        12950.0712 , 15612.19335,  2689.4954 , 21659.9301 ,  4779.6023 ,
#         7345.7266 ,  5002.7827 , 27322.73386,  1744.465  , 15555.18875,
#        19933.458  , 16420.49455,  7050.642  ,  3645.0894 ,  4428.88785,
#         9101.798  ,  4889.9995 , 17128.42608,  1634.5734 , 40720.55105,
#         3161.454  ,  8827.2099 ,  5709.1644 , 13470.8044 ,  8162.71625,
#         9715.841  , 18767.7377 ,  3659.346  ,  8606.2174 ,  4719.73655,
#         1704.5681 ,  8124.4084 ,  2217.46915,  4934.705  ,  5649.715  ,
#        18259.216  ,  8978.1851 , 11931.12525,  4922.9159 , 24106.91255,
#        13616.3586 , 42983.4585 ,  8068.185  , 38746.3551 ,  3481.868  ,
#        19964.7463 , 20462.99766,  1607.5101 ])

# %%
lm.coef_
# Out:
# array([  244.91538377,   -94.67235293,   334.59971709,   515.48305456,
#        23983.46926938,  -517.37807294])

# %%
lm.intercept_
# Out:
# -11218.478714265251

# %%
sns.jointplot(x=predictions,y=y_test,kind='reg');
plt.xlabel('predictions');

# %%
sns.distplot((y_test-predictions));
# Out:
# <ipython-input-50-777543541747>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-predictions));

# %%
metrics.mean_absolute_error(y_test,predictions)#MAE
# Out:
# 3994.9305684100696

# %%
metrics.mean_squared_error(y_test,predictions)#MSE
# Out:
# 34722525.74171915

# %%
np.sqrt(metrics.mean_squared_error(y_test,predictions))#RMSE
# Out:
# 5892.582264314954

# %%
metrics.r2_score(y_test,predictions)#R^2
# Out:
# 0.7531430170965645
